# %%
import pandas as pd
import numpy as np
import speech_recognition as sr
import pyaudio
import webbrowser

# %%
df = pd.read_csv("Final_Dataset.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 marketplace  customer_id       review_id  \
# 0           0             0          US       179886   RY01SAV7HZ8QO
# 1           1             1          US     37293769  R1XX8SDGJ4MZ4L
# 2           2             2          US      8332121  R149Q3B5L33NN5
# 3           3             3          US     47054962  R2ZVD69Z6KPJ4O
# 4           4             4          US     23413911  R1DIKG2G33ZLNP
#
#    product_id  product_parent  \
# 0  B00NTI0CQ2       667358431
# 1  B00BUCLVZU       621695622
# 2  B00RBX9D5W       143071132
# 3  B00UJ3IULO       567816707
# 4  B0037UCTXG       909557698
#
#                                        product_title    product_category  \
# 0  Aketek 1080P LED Protable Projector HD PC AV V...  Home Entertainment
# 1             TiVo Mini with IR Remote (Old Version)  Home Entertainment
# 2  Apple TV MD199LL/A Bundle including remote and...  Home Entertainment
# ...

# %%
from collections import Counter 
  
def most_frequent(List): 
    occurence_count = Counter(List) 
    return occurence_count.most_common(1)[0][0]
def Remove(duplicate): 
    return list(dict.fromkeys(duplicate))

# %%
cid = df["customer_id"].tolist()
cid = Remove(cid)

# %%
print("Most number of Purchases done by: ",most_frequent(df['customer_id']))
# Out:
# Most number of Purchases done by:  52340667

# %%
inid = input("Enter a User ID: ")
# Out:
# Enter a User ID: 52340667

# %%
print("Product purchased by ",inid)
userRatings = df[df['customer_id'] == int(inid)]
userRatings
# Out:
# Product purchased by  52340667
#         Unnamed: 0  Unnamed: 0.1 marketplace  customer_id       review_id  \
# 537006      537016        537016          US     52340667  R3O4NKMER93BO1
# 554045      554055        554055          US     52340667  R1A39GZX8YNQ2N
# 584924      584934        584934          US     52340667   R9TI8JWHKHBQQ
# 599653      599663        599663          US     52340667   RV5ZA1HC3R0XD
# 604092      604102        604102          US     52340667   R6H9FMYDZLJ3G
# ...            ...           ...         ...          ...             ...
# 697741      697756        697756          US     52340667  R2J5ICHJTLVNKV
# 698225      698240        698240          US     52340667  R39YXDDTPA6UV3
# 699192      699207        699207          US     52340667  R1GT9AJ77TIL7S
# 703053      703068        703068          US     52340667  R212L4WSC2IV59
# 703054      703069        703069          US     52340667  R3DX51OFVU3BMO
#
#         product_id  product_parent  \
# ...
